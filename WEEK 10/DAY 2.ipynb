# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.Series([3,4,5,6])
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# dtype: int64

# %%
pd.Series([[3,4,5,6],[4,5,5,6]])
# Out:
# 0    [3, 4, 5, 6]
# 1    [4, 5, 5, 6]
# dtype: object

# %%
pd.DataFrame([[3,4,5,6],[4,5,5,6]])
# Out:
#    0  1  2  3
# 0  3  4  5  6
# 1  4  5  5  6

# %%
pd.DataFrame([[3,4,5,6],[4,5,5,6],[3,4,4,5]])
# Out:
#    0  1  2  3
# 0  3  4  5  6
# 1  4  5  5  6
# 2  3  4  4  5

# %%
df1=pd.DataFrame([[3,4,5,6],[4,5,5,6],[3,4,4,5]])

# %%
df1
# Out:
#    0  1  2  3
# 0  3  4  5  6
# 1  4  5  5  6
# 2  3  4  4  5

# %%
df1.index=[1,2,3]

# %%
df1
# Out:
#    0  1  2  3
# 1  3  4  5  6
# 2  4  5  5  6
# 3  3  4  4  5

# %%
df1.columns=["CSC210","CSC410","MCD220","BCH410"]

# %%
df1
# Out:
#    CSC210  CSC410  MCD220  BCH410
# 1       3       4       5       6
# 2       4       5       5       6
# 3       3       4       4       5

# %%
df1.index=["Mirabelle","Ify","Yemisi"]

# %%
df1
# Out:
#            CSC210  CSC410  MCD220  BCH410
# Mirabelle       3       4       5       6
# Ify             4       5       5       6
# Yemisi          3       4       4       5

# %% [markdown]
# # Creating Dataframes from Dictionaries

# %%
# [4,5,4,5]
# [4,5,4,5]
# list the differnce between list and tuples

# %%
ages={
    "Smith":34,
      "Mirabelle":45,
     "Faithful":24,
     "Aniema":30,
     }

# %%
pd.Series(ages)
# Out:
# Smith        34
# Mirabelle    45
# Faithful     24
# Aniema       30
# dtype: int64

# %%
type(ages)
# Out:
# dict

# %%
ages.keys()
# Out:
# dict_keys(['Smith', 'Mirabelle', 'Faithful', 'Aniema'])

# %%
ages.values()
# Out:
# dict_values([34, 45, 24, 30])

# %%
df2=pd.DataFrame(ages)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-5bfc17222ee1> in <module>
# ----> 1 df2=pd.DataFrame(ages)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ...

# %%
df2=pd.DataFrame(ages,index=[1,2,3,4])

# %%
df2
# Out:
#    Smith  Mirabelle  Faithful  Aniema
# 1     34         45        24      30
# 2     34         45        24      30
# 3     34         45        24      30
# 4     34         45        24      30

# %%
import numpy as np
dict2={
    "Country":["Nigeria","South Africa","Afganistan"],
    "Area":np.random.randint(2000,20000,3)}

# %%
dict2
# Out:
# {'Country': ['Nigeria', 'South Africa', 'Afganistan'],
#  'Area': array([7411, 8555, 3990])}

# %%
pd.DataFrame(dict2)
# Out:
#         Country  Area
# 0       Nigeria  7411
# 1  South Africa  8555
# 2    Afganistan  3990

# %% [markdown]
# # IMPORTING EXTERNAL DATA

# %%
data1=pd.read_csv("games.csv")

# %%
data1
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime
# 1      l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign
# 2      mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate
# 3      kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate
# 4      9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
#       winner increment_code       white_id  white_rating            black_id  \
# ...

# %%
data1.head()
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2  mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
# 3  kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate  white
# 4  9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate  white
#
#   increment_code       white_id  white_rating      black_id  black_rating  \
# 0           15+2       bourgris          1500          a-00          1191
# 1           5+10           a-00          1322     skinnerua          1261
# 2           5+10         ischia          1496          a-00          1500
# 3           20+0  daniamurashov          1439  adivanov2009          1454
# 4           30+3      nik221107          1523  adivanov2009          1469
#
# ...

# %%
data1.tail()
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
#       winner increment_code      white_id  white_rating            black_id  \
# 20053  white          10+10       belcolt          1691            jamboger
# 20054  black           10+0      jamboger          1233  farrukhasomiddinov
# 20055  white           10+0      jamboger          1219        schaaksmurf3
# 20056  white           10+0  marcodisogno          1360            jamboger
# 20057  black           10+0      jamboger          1235               ffbob
#
# ...

# %%
data1.head(2)
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
#
#   increment_code  white_id  white_rating   black_id  black_rating  \
# 0           15+2  bourgris          1500       a-00          1191
# 1           5+10      a-00          1322  skinnerua          1261
#
#                                                moves opening_eco  \
# 0  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# 1  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...         B00
#
#                              opening_name  opening_ply
# 0        Slav Defense: Exchange Variation            5
# 1  Nimzowitsch Defense: Kennedy Variation            4

# %%
data1.tail(6)
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 20052  EopEqqAa   True  1.499812e+12  1.499812e+12     37         resign
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
#       winner increment_code      white_id  white_rating            black_id  \
# 20052  white          10+10      jamboger          1219            samael88
# 20053  white          10+10       belcolt          1691            jamboger
# 20054  black           10+0      jamboger          1233  farrukhasomiddinov
# 20055  white           10+0      jamboger          1219        schaaksmurf3
# ...

# %%
data1.sample(5)
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 18058  guMtLFyZ   True  1.503222e+12  1.503224e+12    209      outoftime
# 400    VVMmBXVj   True  1.503780e+12  1.503790e+12    121         resign
# 15991  sFonRNXE   True  1.497993e+12  1.497995e+12     87           mate
# 19496  9aeHEb3A   True  1.504063e+12  1.504064e+12    113      outoftime
# 921    UpILIA09  False  1.498910e+12  1.498910e+12     31         resign
#
#       winner increment_code   white_id  white_rating      black_id  \
# 18058  white            7+9      bleda          1272    whitearrow
# 400    white           15+5    jutton1          1383      ahmedham
# 15991  white          15+15    totonut          1728       sercanx
# 19496  white           10+0  samoo1477          1698      lazaropa
# 921    white           15+0   mccheese           859  orleibuiatti
#
#        black_rating                                              moves  \
# ...

# %%
data1["victory_status"]
# Out:
# 0        outoftime
# 1           resign
# 2             mate
# 3             mate
# 4             mate
#            ...
# 20053       resign
# 20054         mate
# 20055         mate
# 20056       resign
# 20057         mate
# Name: victory_status, Length: 20058, dtype: object

# %%
data1["victory_status"].head()
# Out:
# 0    outoftime
# 1       resign
# 2         mate
# 3         mate
# 4         mate
# Name: victory_status, dtype: object

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              20058 non-null  object
#  1   rated           20058 non-null  bool
#  2   created_at      20058 non-null  float64
#  3   last_move_at    20058 non-null  float64
#  4   turns           20058 non-null  int64
#  5   victory_status  20058 non-null  object
#  6   winner          20058 non-null  object
#  7   increment_code  20058 non-null  object
#  8   white_id        20058 non-null  object
#  9   white_rating    20058 non-null  int64
#  10  black_id        20058 non-null  object
#  11  black_rating    20058 non-null  int64
#  12  moves           20058 non-null  object
#  13  opening_eco     20058 non-null  object
#  14  opening_name    20058 non-null  object
#  15  opening_ply     20058 non-null  int64
# dtypes: bool(1), float64(2), int64(4), object(9)
# ...
